# %% [markdown]
# # EDA

# %% [markdown]
# This is the notebook to run additional extended EDA that are complex and might affect main notebook

# %%
import pandas as pd
from ydata_profiling import ProfileReport
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Lead Scoring.csv")

# %%
TARGET = "Converted"

# %%
NUMERICAL = df.select_dtypes(include=["int64", "float64"]).columns
CATEGORICAL = df.select_dtypes(include=["object", "category", "bool"]).columns

# %%
df["Last Notable Activity"].dtype
# Out:
# dtype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9103 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
# ...

# %%
profile = ProfileReport(df, title="EDA")

# %%
profile
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Error processing line 1 of /opt/anaconda3/envs/ComputerVision/lib/python3.10/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "/opt/anaconda3/envs/ComputerVision/lib/python3.10/site.py", line 195, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
#
# ...
#   5%|▌         | 2/37 [00:00<00:05,  5.90it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/anaconda3/envs/ComputerVision/lib/python3.10/site-packages/ydata_profiling/profile_report.py in ?(self)
#     546     def _repr_html_(self) -> None:
#     547         """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 548         self.to_notebook_iframe()
#
# ...

# %%
sns.pairplot(data=df[NUMERICAL + [TARGET]]);

# %%
plt.figure(figsize=(20,15))
numer_corr_matrix_spear = df[NUMERICAL + [TARGET]].corr(method='spearman')
corr_map_spear = sns.heatmap(numer_corr_matrix_spear, annot=True, cmap="coolwarm")
corr_map_spear.set_xticklabels(corr_map_spear.get_xticklabels(), rotation=55)
plt.show();
